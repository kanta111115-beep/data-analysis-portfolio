# %% [markdown]
# <a href="https://colab.research.google.com/github/kanta111115-beep/data-analysis-portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
print("Hello")

num1 = 100
num2 = 200
num3,num4 =300,400

print("num1=",num1)
print("num2=",num2)
print("num3=",num3)
print("num4=",num4)
#実行結果
#num1=100 nume2=200 nume3=300 nume=400

num = 100
pi = "３．１４"
str_ = "侍"   # ← 追加

print("num=", num)
print("pi=", pi)
print("str_=", str_)
# Out:
# Hello
# num1= 100
# num2= 200
# num3= 300
# num4= 400
# num= 100
# pi= ３．１４
# str_= 侍

# %% [markdown]
# ### Selecting columns
# You can select specific columns by passing a list of column names.

# %%
# Select 'Name' and 'Age' columns
selected_columns = df[['Name', 'Age']]
print("\nSelected 'Name' and 'Age' columns:")
display(selected_columns)
# Out:
# Selected 'Name' and 'Age' columns:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28
# 4      Eve   22

# %% [markdown]
# ### Filtering rows
# You can filter rows based on conditions. For example, let's filter for people older than 28.

# %%
# Filter rows where Age is greater than 28
filtered_df = df[df['Age'] > 28]
print("\nDataFrame filtered by Age > 28:")
display(filtered_df)
# Out:
# DataFrame filtered by Age > 28:
#       Name  Age    City  Salary   Bonus
# 1      Bob   30   Paris   80000  8000.0
# 2  Charlie   35  London   90000  9000.0

# %% [markdown]
# ### Adding a new column
# Let's add a new column called 'Bonus' based on 'Salary'.

# %%
# Add a new column 'Bonus'
df['Bonus'] = df['Salary'] * 0.10
print("\nDataFrame with new 'Bonus' column:")
display(df)
# Out:
# DataFrame with new 'Bonus' column:
#       Name  Age      City  Salary   Bonus
# 0    Alice   25  New York   70000  7000.0
# 1      Bob   30     Paris   80000  8000.0
# 2  Charlie   35    London   90000  9000.0
# 3    David   28     Tokyo   75000  7500.0
# 4      Eve   22    Sydney   60000  6000.0

# %%
pip install numpy
